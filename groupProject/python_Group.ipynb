# %%
import requests
import json
import pandas as pd

# %%
# Generated store id list to obtain all stores in the LCBO API 

storeidLIST = []

for id in range(701):
    storeidLIST.append(str(id))

# %%
for each_id in storeidLIST:
    try:
        apiKEY = "MDpjZDM2NmI0NC0xNjk3LTExZTgtOWY0Ny00M2M2NzIxZjM0ODY6SU5LQTgzYlYyUlhmODlraU81NWkzUmRxY0R1elJGWTBMaUFI"
        url = "https://lcboapi.com/stores/" + each_id +"?access_key="
        request_info = requests.get(url + apiKEY)
        request_info
        store = request_info.json()['result']
        storeLIST.append(store)
        print("store results")
    
    except:
        print("No store results")

# %%
# Generate list of all store information

storeLIST = []

for each_id in storeidLIST:
    try:
        apiKEY = "MDpjZDM2NmI0NC0xNjk3LTExZTgtOWY0Ny00M2M2NzIxZjM0ODY\
        6SU5LQTgzYlYyUlhmODlraU81NWkzUmRxY0R1elJGWTBMaUFI"
        
        url = "https://lcboapi.com/stores/" + each_id +"?access_key="
        request_info = requests.get(url + apiKEY)
        request_info
        store = request_info.json()['result']
        storeLIST.append(store)
        
    
    except:
        print("No store results")

# %%
# start from 1 to the last soort

allStores = storeLIST[1:]

# %%
# all the columns
columns = []

for key,items in allStores[0].items():
    columns.append(key)
    
# display columns 
# columns

# %%
store_no_list = []
id_list = []
is_dead_list = []

name_list = []
tags_list = []
address_line_1_list = []

address_line_2_list = []
city_list = []
postal_code_list = []

telephone_list = []
fax_list = []
latitude_list = []
longitude_list = []

products_count_list = []
inventory_count_list = []
inventory_price_in_cents_list = []

inventory_volume_in_milliliters_list = []
has_wheelchair_accessability_list = []
has_bilingual_services_list = []

has_product_consultant_list = []
has_tasting_bar_list = []
has_beer_cold_room_list = []

has_special_occasion_permits_list = []
has_vintages_corner_list = []
has_parking_list = []

has_transit_access_list = []
sunday_open_list = []
sunday_close_list = []

monday_open_list = []
monday_close_list = []
tuesday_open_list = []

tuesday_close_list = []
wednesday_open_list = []
wednesday_close_list = []

thursday_open_list = []
thursday_close_list = []
friday_open_list = []

friday_close_list = []
saturday_open_list = []
saturday_close_list = []

updated_at_list = []


for i in range(len(allStores)):
    try:
        id_list.append(allStores[i]['id'])
        store_no_list.append(allStores[i]['store_no'])
        is_dead_list.append(allStores[i]['is_dead'])
        
        name_list.append(allStores[i]['name'])
        tags_list.append(allStores[i]['tags'])
        address_line_1_list.append(allStores[i]['address_line_1'])
        
        address_line_2_list.append(allStores[i]['address_line_2'])
        city_list.append(allStores[i]['city'])
        postal_code_list.append(allStores[i]['postal_code']) 
        
        telephone_list.append(allStores[i]['telephone'])
        fax_list.append(allStores[i]['fax'])
        latitude_list.append(allStores[i]['latitude'])
        
        longitude_list.append(allStores[i]['longitude'])
        products_count_list.append(allStores[i]['products_count'])
        inventory_count_list.append(allStores[i]['inventory_count'])
       
        inventory_price_in_cents_list.append(allStores[i]['inventory_price_in_cents'])
        inventory_volume_in_milliliters_list.append(allStores[i]['inventory_volume_in_milliliters'])       
        has_wheelchair_accessability_list.append(allStores[i]['has_wheelchair_accessability'])
        
        has_bilingual_services_list.append(allStores[i]['has_bilingual_services'])
        has_product_consultant_list.append(allStores[i]['has_product_consultant'])
        has_tasting_bar_list.append(allStores[i]['has_tasting_bar'])
        
        
        has_beer_cold_room_list.append(allStores[i]['has_beer_cold_room'])
        has_special_occasion_permits_list.append(allStores[i]['has_special_occasion_permits'])
        has_vintages_corner_list.append(allStores[i]['has_vintages_corner'])
        
        has_parking_list.append(allStores[i]['has_parking'])
        has_transit_access_list.append(allStores[i]['has_transit_access'])
        sunday_open_list.append(allStores[i]['sunday_open'])
        
        
        sunday_close_list.append(allStores[i]['sunday_close'])
        monday_open_list.append(allStores[i]['monday_open'])
        monday_close_list.append(allStores[i]['monday_close'])
        
        tuesday_open_list.append(allStores[i]['tuesday_open'])
        tuesday_close_list.append(allStores[i]['tuesday_close'])
        wednesday_open_list.append(allStores[i]['wednesday_open'])
        
        wednesday_close_list.append(allStores[i]['wednesday_close'])
        thursday_open_list.append(allStores[i]['thursday_open'])
        thursday_close_list.append(allStores[i]['thursday_close'])
        
        friday_open_list.append(allStores[i]['friday_open'])
        friday_close_list.append(allStores[i]['friday_close'])
        saturday_open_list.append(allStores[i]['saturday_open'])
        
        saturday_close_list.append(allStores[i]['saturday_close'])
        
    except:
        print("no info")
# Out:
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info
# no info

# %%
df_Stores= pd.DataFrame({"store_no" :   store_no_list,
              "id"       :   id_list,
             "is_dead"  :   is_dead_list,

              "name"     :   name_list ,
                      "tags"     :   tags_list ,
                "address_line_1" :   address_line_1_list,

               "address_line_2"  :   address_line_2_list,
                 "city"          :   city_list,
                  "postal_code"  :   postal_code_list,

                   "telephone"   :   telephone_list,
                   "fax"         :   fax_list,
                    "lat"        :   latitude_list,
                    "long"       :   longitude_list,

                "products_count" :   products_count_list,
                "inventory_count"         :   inventory_count_list,
                         "inventory_price"        :   inventory_price_in_cents_list,

                          "inventory_volume_in_milliliters"       :   inventory_volume_in_milliliters_list,
                           "has_wheelchair_accessability"      :   has_wheelchair_accessability_list,
                           "has_bilingual_services"      :   has_bilingual_services_list,

                           "has_product_consultant"      :   has_product_consultant_list,
                            "has_tasting_bar"     :   has_tasting_bar_list,
                            "has_beer_cold_room"     :   has_beer_cold_room_list,

                           "has_special_occasion_permits"      :   has_special_occasion_permits_list,
                           "has_vintages_corner"      :   has_vintages_corner_list,
                           "has_parking"      :   has_parking_list,

                             "has_transit_access"    :   has_transit_access_list,
                           "sunday_open"      :   sunday_open_list,
                           "sunday_close"      :   sunday_close_list,

                            "monday_open"     :   monday_open_list,
                          "monday_close"       :   monday_close_list,
                           "tuesday_open"      :   tuesday_open_list,

                            "tuesday_close"     :  tuesday_close_list,
                           "wednesday_open"      :  wednesday_open_list,
                            "wednesday_close"     :  wednesday_close_list,

                          "thursday_open"       :  thursday_open_list,
                          "thursday_close"       :  thursday_close_list,
                           "friday_open"      :  friday_open_list,

                         "friday_close"        :  friday_close_list,
                          "saturday_open"       :  saturday_open_list,
                          "saturday_close"       :  saturday_close_list,

                           })

# %%
df_Stores
# Out:
#                      address_line_1                  address_line_2  \
# 0                 2625D Weston Road                            None
# 1           396 St. Clair Ave. West                            None
# 2           1230 Dundas Street West                            None
# 3               200 Danforth Avenue                            None
# 17              Toronto  (416) 538-9500        1320.0        570.0
# 18              Toronto  (416) 653-8850        1260.0        600.0
# 19            Etobicoke  (416) 251-4236        1260.0        600.0
# 20             Ancaster  (905) 304-9611        1320.0        600.0
# 21               Barrie  (705) 739-8507        1260.0        600.0
# 22             Hamilton  (905) 544-3555        1320.0        570.0
# 23        Port Colborne  (905) 834-3399        1200.0        600.0
# 24               Dundas  (905) 628-4040        1320.0        570.0
# 25               London  (519) 432-3768        1260.0        600.0
# 26               London  (519) 451-8093        1260.0        600.0
# 27            Dunnville  (905) 774-3123        1260.0        600.0
# 28              Wiarton  (519) 534-3274        1260.0        600.0
# 29            Walkerton  (519) 881-1588        1260.0        600.0
# ..                  ...             ...           ...          ...
# 630           Stratford  (519) 271-5072        1260.0        600.0
# 631              Ottawa  (613) 729-8709        1260.0        570.0
# 632             Toronto  (416) 593-5273        1260.0        540.0
# 633              Milton  (905) 636-7010        1260.0        570.0
# 634             Toronto  (416) 483-8925        1260.0        600.0
# 635             Toronto  (416) 925-4858        1260.0        600.0
# 636             Sudbury  (705) 560-5937        1260.0        600.0
# 637            Courtice  (905) 576-7334        1320.0        570.0
# 638            Kingston  (613) 547-2865        1260.0        570.0
# 639            Brampton  (905) 456-6512        1320.0        570.0
# 640             Toronto  (416) -               1320.0        600.0
# 641          North York  (416) 785-4524        1260.0        600.0
# 642              Aurora  (905) 751-1557        1260.0        600.0
# 643         Scarborough  (416) 266-9180        1260.0        600.0
# 644            Brampton  (905) 458-3907        1260.0        570.0
# 645            Ancaster  (905) 648-9547        1260.0        600.0
# 646            Hamilton  (905) 385-8062        1260.0        600.0
# 647           Etobicoke  (416) -               1260.0        600.0
# 648              Ottawa  (613) 825-4606        1260.0        570.0
# 649           King City  (905) 833-9049        1260.0        600.0
# 650             Toronto  (416) 465-6947        1260.0        600.0
# 651             Toronto  (416) 594-6556        1260.0        600.0
# 652           Etobicoke  (416) 762-8671        1260.0        600.0
# 653  Fort Erie-Ridgeway  (905) 894-0273        1200.0        600.0
# 654             Orleans  (613) 834-4610        1260.0        570.0
# 655              Whitby  (905) 665-7131        1260.0        570.0
# 656             Toronto  (416) 690-9360        1260.0        600.0
# 657         Mississauga  (905) 897-7501        1260.0        600.0
# 658              Ottawa  (613) 822-9971        1260.0        570.0
# 659         Scarborough  (416) 297-8905        1260.0        600.0
#
#      has_beer_cold_room  has_bilingual_services  has_parking  \
# 0                 False                    True         True
# 1                 False                    True         True
# 2                 False                    True         True
# 3                  True                    True        False
# 4                 False                    True         True
# 5                  True                    True         True
# 6                 False                    True        False
# 7                 False                    True        False
# 8                 False                    True        False
# 9                 False                    True         True
# 10                False                    True         True
# 11                False                    True         True
# 12                False                    True         True
# 13                False                    True         True
# 14                False                    True         True
# 15                False                    True        False
# 16                False                    True        False
# 17                False                    True         True
# 18                 True                    True         True
# 19                False                    True         True
# 20                False                   False         True
# 21                False                   False         True
# 22                 True                    True         True
# 23                False                    True         True
# 24                False                   False         True
# 25                False                    True         True
# 26                False                    True         True
# 27                False                   False         True
# 28                False                   False         True
# 29                False                   False         True
# ..                  ...                     ...          ...
# 630                True                   False         True
# 631               False                    True        False
# 632               False                    True        False
# 633               False                   False        False
# 634               False                    True        False
# 635               False                    True        False
# 636                True                    True         True
# 637                True                   False         True
# 638                True                   False         True
# 639                True                   False        False
# 640               False                   False        False
# 641               False                   False        False
# 642                True                   False        False
# 643                True                   False         True
# 644               False                   False        False
# 645                True                   False        False
# 646                True                   False        False
# 647               False                   False        False
# 648                True                    True         True
# 649                True                   False         True
# 650               False                   False        False
# 651               False                    True        False
# 652               False                   False        False
# 653               False                   False        False
# 654                True                    True         True
# 655                True                   False         True
# 656                True                    True        False
# 657               False                    True        False
# 658                True                    True         True
# 659               False                    True         True
#
#      has_product_consultant       ...        sunday_close  sunday_open  \
# 0                      True       ...              1080.0        660.0
# 1                     False       ...              1080.0        660.0
# 2                     False       ...              1080.0        660.0
# 3                     False       ...              1080.0        660.0
# 4                      True       ...              1080.0        660.0
# 5                     False       ...              1080.0        660.0
# 6                      True       ...              1080.0        660.0
# 7                     False       ...              1080.0        660.0
# 8                     False       ...              1080.0        660.0
# 9                      True       ...              1080.0        660.0
# 10                    False       ...              1080.0        660.0
# 11                    False       ...              1080.0        660.0
# 12                    False       ...              1080.0        660.0
# 13                    False       ...              1080.0        660.0
# 14                     True       ...              1080.0        660.0
# 15                    False       ...              1080.0        660.0
# 16                     True       ...              1080.0        660.0
# 17                     True       ...              1080.0        660.0
# 18                     True       ...              1080.0        660.0
# 19                    False       ...              1080.0        660.0
# 20                     True       ...              1080.0        660.0
# 21                     True       ...              1080.0        660.0
# 22                     True       ...              1080.0        660.0
# 23                    False       ...              1080.0        660.0
# 24                     True       ...              1080.0        660.0
# 25                     True       ...              1080.0        660.0
# 26                    False       ...              1080.0        660.0
# 27                    False       ...              1080.0        660.0
# 28                    False       ...              1080.0        660.0
# 29                    False       ...              1080.0        660.0
# ..                      ...       ...                 ...          ...
# 630                    True       ...              1080.0        660.0
# 631                   False       ...              1080.0        660.0
# 632                   False       ...              1080.0        660.0
# 633                    True       ...              1080.0        660.0
# 634                   False       ...              1080.0        660.0
# 635                   False       ...              1080.0        660.0
# 636                    True       ...              1080.0        660.0
# 637                    True       ...              1080.0        660.0
# 638                   False       ...              1080.0        660.0
# 639                    True       ...              1080.0        660.0
# 640                   False       ...              1080.0        660.0
# 641                   False       ...              1080.0        660.0
# 642                    True       ...              1080.0        660.0
# 643                   False       ...              1080.0        660.0
# 644                    True       ...              1080.0        660.0
# 645                   False       ...              1080.0        660.0
# 646                   False       ...              1080.0        660.0
# 647                   False       ...              1080.0        660.0
# 648                    True       ...              1080.0        660.0
# 649                   False       ...              1080.0        660.0
# 650                   False       ...              1080.0        660.0
# 651                   False       ...              1080.0        660.0
# 652                   False       ...              1080.0        660.0
# 653                   False       ...              1080.0        660.0
# 654                    True       ...              1080.0        660.0
# 655                   False       ...              1080.0        660.0
# 656                    True       ...              1080.0        660.0
# 657                    True       ...              1080.0        660.0
# 658                    True       ...              1080.0        660.0
# 659                   False       ...              1080.0        660.0
#
#                                                   tags       telephone  \
# 0    hwy 401 weston 2625d road toronto north toront...  (416) 243-3320
# 650          1260.0          600.0         1260.0         600.0
# 651          1260.0          600.0         1260.0         600.0
# 652          1260.0          600.0         1260.0         600.0
# 653          1080.0          600.0         1080.0         600.0
# 654          1260.0          570.0         1260.0         570.0
# 655          1260.0          570.0         1260.0         570.0
# 656          1260.0          600.0         1260.0         600.0
# 657          1260.0          600.0         1260.0         600.0
# 658          1260.0          570.0         1260.0         570.0
# 659          1260.0          600.0         1260.0         600.0
#
#      wednesday_close  wednesday_open
# 0             1380.0           540.0
# 1             1320.0           600.0
# 2             1260.0           600.0
# 3             1320.0           570.0
# 4             1320.0           600.0
# 5             1260.0           600.0
# 6             1260.0           600.0
# 7             1260.0           600.0
# 8             1260.0           600.0
# 9             1320.0           570.0
# 10            1260.0           600.0
# 11            1260.0           600.0
# 12            1260.0           600.0
# 13            1320.0           600.0
# 14            1320.0           600.0
# 15            1320.0           600.0
# 16            1320.0           600.0
# 17            1320.0           570.0
# 18            1260.0           600.0
# 19            1260.0           600.0
# 20            1320.0           600.0
# 21            1260.0           600.0
# 22            1320.0           570.0
# 23            1080.0           600.0
# 24            1320.0           570.0
# 25            1080.0           600.0
# 26            1260.0           600.0
# 27            1080.0           600.0
# 28            1080.0           600.0
# 29            1080.0           600.0
# ..               ...             ...
# 630           1260.0           600.0
# 631           1260.0           570.0
# 632           1260.0           540.0
# 633           1260.0           570.0
# 634           1260.0           600.0
# 635           1260.0           600.0
# 636           1260.0           600.0
# 637           1320.0           570.0
# 638           1260.0           570.0
# 639           1320.0           570.0
# 640           1320.0           600.0
# 641           1260.0           600.0
# 642           1260.0           600.0
# 643           1260.0           600.0
# 644           1260.0           570.0
# 645           1260.0           600.0
# 646           1260.0           600.0
# 647           1260.0           600.0
# 648           1260.0           570.0
# 649           1260.0           600.0
# 650           1260.0           600.0
# 651           1260.0           600.0
# 652           1260.0           600.0
# 653           1080.0           600.0
# 654           1260.0           570.0
# 655           1260.0           570.0
# 656           1260.0           600.0
# 657           1260.0           600.0
# 658           1260.0           570.0
# 659           1260.0           600.0
#
# [660 rows x 40 columns]

# %%
df_Stores.columns
# Out:
# Index(['address_line_1', 'address_line_2', 'city', 'fax', 'friday_close',
#        'friday_open', 'has_beer_cold_room', 'has_bilingual_services',
#        'has_parking', 'has_product_consultant', 'has_special_occasion_permits',
#        'has_tasting_bar', 'has_transit_access', 'has_vintages_corner',
#        'has_wheelchair_accessability', 'id', 'inventory_count',
#        'inventory_price', 'inventory_volume_in_milliliters', 'is_dead', 'lat',
#        'long', 'monday_close', 'monday_open', 'name', 'postal_code',
#        'products_count', 'saturday_close', 'saturday_open', 'store_no',
#        'sunday_close', 'sunday_open', 'tags', 'telephone', 'thursday_close',
#        'thursday_open', 'tuesday_close', 'tuesday_open', 'wednesday_close',
#        'wednesday_open'],
#       dtype='object')

# %%
import matplotlib as plt
# %matplotlib inline

import seaborn as sns

# %%
df_Stores['has_beer_cold_room'].value_counts(normalize=True).reset_index()
# Out:
#    index  has_beer_cold_room
# 0  False            0.624242
# 1   True            0.375758

# %%
df_Stores.has_bilingual_services.value_counts(normalize=True).reset_index()
# Out:
#    index  has_bilingual_services
# 0  False                0.598485
# 1   True                0.401515

# %%
df_Stores.has_product_consultant.value_counts(normalize=True).reset_index()
# Out:
#    index  has_product_consultant
# 0  False                0.701515
# 1   True                0.298485

# %%
df_Stores.city.nunique()
# Out:
# 414

# %%
df_Stores.monday_close.plot(kind='hist')
df_Stores.tuesday_close.plot(kind='hist')
df_Stores.wednesday_close.plot(kind='hist')
df_Stores.thursday_close.plot(kind='hist')

# %% [markdown]
# ## Get Three Stores Nearest To you gmAPI

# %%
# inputs country Abbr and zip code

def threeNearestLocation(zipCode,countryABBR):
    
    zipCode = str(zipCode)
    countryABBR = str(countryABBR)
    
#     google api

    api_key = "APPID=5be78fade1727ace968b5ab363d997bd"
    url =  "http://api.openweathermap.org/data/2.5/weather?zip=" + zipCode + "," + countryABBR + "&" + api_key
    request_info = requests.get(url)
    weather_info = request_info.json()
    dict_weather_coord =weather_info['coord']
    
    googleAPIlat = str(dict_weather_coord['lat'])
    googleAPIlon = str(dict_weather_coord['lon'])
    
#     LCBO API

    apiKEY = "MDpjZDM2NmI0NC0xNjk3LTExZTgtOWY0Ny00M2M2NzIxZjM0ODY6SU5LQTgzYlYyUlhmODlraU81NWkzUmRxY0R1elJGWTBMaUFI"
    url = "http://lcboapi.com/stores?lat=" + googleAPIlat + "&lon=" + googleAPIlon
    request_info = requests.get(url)
    locationNearYOU = request_info.json()
    location3NearYOU =locationNearYOU['result'][:3]


    address_list = []
    city_list =[]
    distance_list = []
    name_list = []
    phone_list = []

    for each in location3NearYOU:
        address_list.append(each['address_line_1'])
        city_list.append(each['city'])
        distance_list.append(each['distance_in_meters'])
        name_list.append(each['name'])
        phone_list.append(each['telephone'])
    

### distance in meters

    df_Nearseat_locations = pd.DataFrame( {"distance_in_meters" : distance_list,
                                           "name"     : name_list,
                                           "address" : address_list,
                                           "city"     :  city_list,
                                           "phone"    : phone_list})
    
    

    return df_Nearseat_locations.to_json(orient='records')

# %%
threeNearestLocation("m3c",'ca')
# Out:
# '[{"address":"195 the Donway West","city":"North York","distance_in_meters":1475,"name":"Lawrence & Don Mills","phone":"(416) 447-0491"},{"address":"45 Overlea Boulevard","city":"Toronto","distance_in_meters":2909,"name":"Overlea & Millwood","phone":"(416) 421-2238"},{"address":"1900 Eglinton Avenue East","city":"Scarborough","distance_in_meters":3022,"name":"Eglinton & Warden","phone":"(416) 755-6751"}]'

# %%
# Out:
# '[{"address":"195 the Donway West","city":"North York","distance_in_meters":1475,"name":"Lawrence & Don Mills","phone":"(416) 447-0491"},{"address":"45 Overlea Boulevard","city":"Toronto","distance_in_meters":2909,"name":"Overlea & Millwood","phone":"(416) 421-2238"},{"address":"1900 Eglinton Avenue East","city":"Scarborough","distance_in_meters":3022,"name":"Eglinton & Warden","phone":"(416) 755-6751"}]'

# %%
random = {"color":['red','blue','green'],
          "size": [1,2,3],
          "weight":[123,343,433] }

# %%
df = pd.DataFrame(random)

# %%
df
# Out:
#    color  size  weight
# 0    red     1     123
# 1   blue     2     343
# 2  green     3     433

# %%
# Out:
#     index    0
# 0   color  red
# 1    size    1
# 2  weight  123
